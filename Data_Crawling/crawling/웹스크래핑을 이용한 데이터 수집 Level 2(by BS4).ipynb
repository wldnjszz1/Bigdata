# %% [markdown]
# ### 대상
# * 로그인, 첨부 파일 다운로드, ajax 등 사용자의 개입이 안되는 케이스
# * 사이트를 긁어서 원하는 데이터를 추출하는 방식

# %% [markdown]
# * 목표
# > 사이트 긁기
# > html 파싱 처리 (BS4)
# > 데이터 적재
# > 스케줄링(윈도우 스케줄러, 리눅스 cron)
# * 대상 사이트
# > 네이버 환율 사이트
# > https://finance.naver.com/marketindex/exchangeList.nhn

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# 요청 => html 획득
url_base = 'https://finance.naver.com/marketindex/exchangeList.nhn'
# 요청
page = urlopen( url_base )

# %%
# 응답 객체를 BS에 넣어서 DOM 트리로 올린다(= HTML 객체를 메모리로 로드)
# 1번 인자: html 문자열, html 응답 객체
# 2번 인자: 파싱(html에서 원하는 데이터를 추출) 엔진 종류
# html.parser로 사용 => 만약 안된다면, html5lib 사용
soup = BeautifulSoup(page,'html.parser')
soup
# Out:
# <html lang="ko">
# <head>
# <title>네이버 금융</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="/css/finance.css?20190130182100" rel="stylesheet" type="text/css"/>
# <script language="javascript">document.domain="naver.com";</script>
# <script src="/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="/js/lcslog.js?20190130182100" type="text/javascript"></script>
# </head>
# <body>
# <div class="tbl_area">
# <table border="1" class="tbl_exchange" summary="환전 고시 환율 리스트">
# <caption>환전 고시 환율</caption>
# <colgroup>
# <col width="162"/>
# <col width="92"/>
# <col width="92"/>
# <col width="92"/>
# <col width="93"/>
# <col width="92"/>
# <col width="90"/>
# </colgroup>
# <thead>
# <tr>
# <th class="th_ex1" rowspan="2">
# <a href="#" onclick="javascript:changeOrder('exchange'); return false;"><span>통화명</span></a></th>
# <th class="th_ex2" rowspan="2"><span>매매기준율</span></th>
# <th class="th_ex3" colspan="2"><span>현찰</span></th>
# <th class="th_ex4" colspan="2"><span>송금</span></th>
# <th class="th_ex6" rowspan="2"><span>미화환산율</span></th>
# </tr>
# <tr>
# <th class="th_ex7"><span>사실 때 </span></th>
# <th class="th_ex8"><span>파실 때 </span></th>
# <th class="th_ex9"><span>보내실 때 </span></th>
# <th class="th_ex10"><span>받으실 때</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_USDKRW', '1', event);" target="_parent">
#
#
#
#
# 					미국 USD
#
# 				</a></td>
# <td class="sale">1,125.20</td>
# <td>1,144.89</td>
# <td>1,105.51</td>
# <td>1,136.20</td>
# <td>1,114.20</td>
# <td>1.000</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EURKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_EURKRW', '2', event);" target="_parent">
#
#
#
#
# 					유럽연합 EUR
#
# 				</a></td>
# <td class="sale">1,273.67</td>
# <td>1,299.01</td>
# <td>1,248.33</td>
# <td>1,286.40</td>
# <td>1,260.94</td>
# <td>1.132</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_JPYKRW', '3', event);" target="_parent">
#
# 					일본 JPY (100엔)
#
#
#
#
# 				</a></td>
# <td class="sale">1,023.33</td>
# <td>1,041.23</td>
# <td>1,005.43</td>
# <td>1,033.35</td>
# <td>1,013.31</td>
# <td>0.910</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CNYKRW', '4', event);" target="_parent">
#
#
#
#
# 					중국 CNY
#
# 				</a></td>
# <td class="sale">165.76</td>
# <td>174.04</td>
# <td>157.48</td>
# <td>167.41</td>
# <td>164.11</td>
# <td>0.147</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_HKDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_HKDKRW', '5', event);" target="_parent">
#
#
#
#
# 					홍콩 HKD
#
# 				</a></td>
# <td class="sale">143.38</td>
# <td>146.20</td>
# <td>140.56</td>
# <td>144.81</td>
# <td>141.95</td>
# <td>0.127</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_TWDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_TWDKRW', '6', event);" target="_parent">
#
#
#
#
# 					대만 TWD
#
# 				</a></td>
# <td class="sale">36.46</td>
# <td>41.23</td>
# <td>33.91</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.032</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_GBPKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_GBPKRW', '7', event);" target="_parent">
#
#
#
#
# 					영국 GBP
#
# 				</a></td>
# <td class="sale">1,454.83</td>
# <td>1,483.49</td>
# <td>1,426.17</td>
# <td>1,469.37</td>
# <td>1,440.29</td>
# <td>1.293</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_OMRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_OMRKRW', '8', event);" target="_parent">
#
#
#
#
# 					오만 OMR
#
# 				</a></td>
# <td class="sale">2,922.60</td>
# <td>3,182.71</td>
# <td>2,747.25</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>2.597</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CADKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CADKRW', '9', event);" target="_parent">
#
#
#
#
# 					캐나다 CAD
#
# 				</a></td>
# <td class="sale">846.30</td>
# <td>862.97</td>
# <td>829.63</td>
# <td>854.76</td>
# <td>837.84</td>
# <td>0.752</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CHFKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CHFKRW', '10', event);" target="_parent">
#
#
#
#
# 					스위스 CHF
#
# 				</a></td>
# <td class="sale">1,125.14</td>
# <td>1,147.30</td>
# <td>1,102.98</td>
# <td>1,136.39</td>
# <td>1,113.89</td>
# <td>1.000</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_SEKKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_SEKKRW', '11', event);" target="_parent">
#
#
#
#
# 					스웨덴 SEK
#
# 				</a></td>
# <td class="sale">121.31</td>
# <td>124.28</td>
# <td>118.34</td>
# <td>122.52</td>
# <td>120.10</td>
# <td>0.108</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_AUDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_AUDKRW', '12', event);" target="_parent">
#
#
#
#
# 					호주 AUD
#
# 				</a></td>
# <td class="sale">797.77</td>
# <td>813.48</td>
# <td>782.06</td>
# <td>805.74</td>
# <td>789.80</td>
# <td>0.709</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_NZDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_NZDKRW', '13', event);" target="_parent">
#
#
#
#
# 					뉴질랜드 NZD
#
# 				</a></td>
# <td class="sale">760.35</td>
# <td>775.32</td>
# <td>745.38</td>
# <td>767.95</td>
# <td>752.75</td>
# <td>0.676</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CZKKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CZKKRW', '14', event);" target="_parent">
#
#
#
#
# 					체코 CZK
#
# 				</a></td>
# <td class="sale">49.33</td>
# <td>53.52</td>
# <td>44.90</td>
# <td>49.87</td>
# <td>48.79</td>
# <td>0.044</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_CLPKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_CLPKRW', '15', event);" target="_parent">
#
#
#
#
# 					칠레 CLP
#
# 				</a></td>
# <td class="sale">1.71</td>
# <td>1.84</td>
# <td>1.58</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.002</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_TRYKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_TRYKRW', '16', event);" target="_parent">
#
#
#
#
# 					터키 TRY
#
# 				</a></td>
# <td class="sale">214.32</td>
# <td>246.68</td>
# <td>193.32</td>
# <td>216.67</td>
# <td>211.97</td>
# <td>0.191</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_MNTKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_MNTKRW', '17', event);" target="_parent">
#
#
#
#
# 					몽골 MNT
#
# 				</a></td>
# <td class="sale">0.43</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.000</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_ILSKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_ILSKRW', '18', event);" target="_parent">
#
#
#
#
# 					이스라엘 ILS
#
# 				</a></td>
# <td class="sale">309.00</td>
# <td>339.90</td>
# <td>284.28</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.275</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_DKKKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_DKKKRW', '19', event);" target="_parent">
#
#
#
#
# 					덴마크 DKK
#
# 				</a></td>
# <td class="sale">170.65</td>
# <td>174.83</td>
# <td>166.47</td>
# <td>172.35</td>
# <td>168.95</td>
# <td>0.152</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_NOKKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_NOKKRW', '20', event);" target="_parent">
#
#
#
#
# 					노르웨이 NOK
#
# 				</a></td>
# <td class="sale">130.10</td>
# <td>133.28</td>
# <td>126.92</td>
# <td>131.40</td>
# <td>128.80</td>
# <td>0.116</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_SARKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_SARKRW', '21', event);" target="_parent">
#
#
#
#
# 					사우디아라비아 SAR
#
# 				</a></td>
# <td class="sale">300.03</td>
# <td>318.93</td>
# <td>279.33</td>
# <td>303.03</td>
# <td>297.03</td>
# <td>0.267</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_KWDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_KWDKRW', '22', event);" target="_parent">
#
#
#
#
# 					쿠웨이트 KWD
#
# 				</a></td>
# <td class="sale">3,703.75</td>
# <td>3,944.49</td>
# <td>3,407.45</td>
# <td>3,740.78</td>
# <td>3,666.72</td>
# <td>3.292</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_BHDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_BHDKRW', '23', event);" target="_parent">
#
#
#
#
# 					바레인 BHD
#
# 				</a></td>
# <td class="sale">2,984.54</td>
# <td>3,175.55</td>
# <td>2,745.78</td>
# <td>3,014.38</td>
# <td>2,954.70</td>
# <td>2.653</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_AEDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_AEDKRW', '24', event);" target="_parent">
#
#
#
#
# 					아랍에미리트 AED
#
# 				</a></td>
# <td class="sale">306.34</td>
# <td>323.18</td>
# <td>285.21</td>
# <td>309.40</td>
# <td>303.28</td>
# <td>0.272</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JODKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_JODKRW', '25', event);" target="_parent">
#
#
#
#
# 					요르단 JOD
#
# 				</a></td>
# <td class="sale">1,585.91</td>
# <td>1,727.05</td>
# <td>1,459.04</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>1.409</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_EGPKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_EGPKRW', '26', event);" target="_parent">
#
#
#
#
# 					이집트 EGP
#
# 				</a></td>
# <td class="sale">63.80</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.057</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_THBKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_THBKRW', '27', event);" target="_parent">
#
#
#
#
# 					태국 THB
#
# 				</a></td>
# <td class="sale">35.77</td>
# <td>37.55</td>
# <td>33.63</td>
# <td>36.12</td>
# <td>35.42</td>
# <td>0.032</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_SGDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_SGDKRW', '28', event);" target="_parent">
#
#
#
#
# 					싱가포르 SGD
#
# 				</a></td>
# <td class="sale">829.18</td>
# <td>845.68</td>
# <td>812.68</td>
# <td>837.47</td>
# <td>820.89</td>
# <td>0.737</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_MYRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_MYRKRW', '29', event);" target="_parent">
#
#
#
#
# 					말레이시아 MYR
#
# 				</a></td>
# <td class="sale">276.29</td>
# <td>293.69</td>
# <td>255.85</td>
# <td>0.00</td>
# <td>273.53</td>
# <td>0.246</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_IDRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_IDRKRW', '30', event);" target="_parent">
#
#
# 					인도네시아 IDR 100
#
#
#
# 				</a></td>
# <td class="sale">8.03</td>
# <td>8.59</td>
# <td>7.23</td>
# <td>8.11</td>
# <td>7.95</td>
# <td>0.007</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_QARKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_QARKRW', '31', event);" target="_parent">
#
#
#
#
# 					카타르 QAR
#
# 				</a></td>
# <td class="sale">309.04</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.275</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_KZTKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_KZTKRW', '32', event);" target="_parent">
#
#
#
#
# 					카자흐스탄 KZT
#
# 				</a></td>
# <td class="sale">3.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.003</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_BNDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_BNDKRW', '33', event);" target="_parent">
#
#
#
#
# 					브루나이 BND
#
# 				</a></td>
# <td class="sale">829.18</td>
# <td>862.34</td>
# <td>779.43</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.737</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_INRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_INRKRW', '34', event);" target="_parent">
#
#
#
#
# 					인도 INR
#
# 				</a></td>
# <td class="sale">15.80</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.014</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_PKRKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_PKRKRW', '35', event);" target="_parent">
#
#
#
#
# 					파키스탄 PKR
#
# 				</a></td>
# <td class="sale">8.05</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.007</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_BDTKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_BDTKRW', '36', event);" target="_parent">
#
#
#
#
# 					방글라데시 BDT
#
# 				</a></td>
# <td class="sale">13.40</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.00</td>
# <td>0.012</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_PHPKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_PHPKRW', '37', event);" target="_parent">
#
#
#
#
# 					필리핀 PHP
#
# 				</a></td>
# <td class="sale">21.63</td>
# <td>23.79</td>
# <td>19.86</td>
# <td>21.84</td>
# <td>21.42</td>
# <td>0.019</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_MXNKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_MXNKRW', '38', event);" target="_parent">
#
#
#
#
# 					멕시코 MXN
#
# 				</a></td>
# <td class="sale">58.90</td>
# <td>64.79</td>
# <td>53.96</td>
# <td>59.48</td>
# <td>58.32</td>
# <td>0.052</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_BRLKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_BRLKRW', '39', event);" target="_parent">
#
#
#
#
# 					브라질 BRL
#
# 				</a></td>
# <td class="sale">301.49</td>
# <td>332.24</td>
# <td>277.38</td>
# <td>0.00</td>
# <td>297.88</td>
# <td>0.268</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_VNDKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_VNDKRW', '40', event);" target="_parent">
#
#
#
# 					베트남 VND 100
#
#
# 				</a></td>
# <td class="sale">4.85</td>
# <td>5.42</td>
# <td>4.28</td>
# <td>4.89</td>
# <td>4.81</td>
# <td>0.004</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_ZARKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_ZARKRW', '41', event);" target="_parent">
#
#
#
#
# 					남아프리카 공화국 ZAR
#
# 				</a></td>
# <td class="sale">82.67</td>
# <td>87.63</td>
# <td>76.06</td>
# <td>83.66</td>
# <td>81.68</td>
# <td>0.074</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_RUBKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_RUBKRW', '42', event);" target="_parent">
#
#
#
#
# 					러시아 RUB
#
# 				</a></td>
# <td class="sale">17.17</td>
# <td>18.37</td>
# <td>15.29</td>
# <td>17.34</td>
# <td>17.00</td>
# <td>0.015</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_HUFKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_HUFKRW', '43', event);" target="_parent">
#
#
#
#
# 					헝가리 HUF
#
# 				</a></td>
# <td class="sale">3.99</td>
# <td>4.36</td>
# <td>3.68</td>
# <td>4.03</td>
# <td>3.95</td>
# <td>0.004</td>
# </tr>
# <tr>
# <td class="tit"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_PLNKRW" onclick="parent.clickcr(this, 'exl.exlist', 'FX_PLNKRW', '44', event);" target="_parent">
#
#
#
#
# 					폴란드 PLN
#
# 				</a></td>
# <td class="sale">295.42</td>
# <td>319.05</td>
# <td>271.79</td>
# <td>298.66</td>
# <td>292.18</td>
# <td>0.263</td>
# </tr>
# </tbody>
# </table>
# </div>
# <script language="javascript" type="text/javascript">
# 		// 통화명 정렬 - asc, desc
#
# 		// xss 공격 때문에 validation check 추가
# 		regex = new RegExp("^asc$|^desc$");
#
# 		if ("".match(regex)) {
# 			var CURRENT_SORT_ORDER = "";
# 		} else {
# 			var CURRENT_SORT_ORDER = "asc";
# 		}
#
# 		function changeOrder(type) {
# 		var sortOrder = null;
# 		if (CURRENT_SORT_ORDER == "asc") {
# 			sortOrder = "desc";
# 		} else if (CURRENT_SORT_ORDER == "desc") {
# 			sortOrder = "asc";
# 		} else {
# 			sortOrder = "desc";
# 		}
#
# 		if(type == "exchange") {
# 			location.href= "/marketindex/exchangeList.nhn?sortOrder="+sortOrder;
# 		} else {
# 			location.href= "/marketindex/worldExchangeList.nhn?sortOrder="+sortOrder;
# 		}
# 	}
# 	</script>
# <script type="text/javascript">
# </script>
# </body>
# </html>

# %%
# 모든 통화명 추출 => 통화명을 찾아서 추출
# body > div > table > tbody > tr:nth-child(1) > td.tit
# td.tit
# 이 문서상에 존재하는 모든 td중에 class가 tit인 요소만 모으기
tits = soup.select('td.tit')

# %%
# currency_list = list()
# for tit in tits:
#     currency = tit.a.string.strip()
# # 코드를 개선해서 통화 목록을 리스트로 모아서 출력하시오
#     currency_list.append(currency)
# print(currency_list)

# %%
currency_list = [ tit.a.string.strip() for tit in soup.select('td.tit') ]
currency_list
# Out:
# ['미국 USD',
#  '유럽연합 EUR',
#  '일본 JPY (100엔)',
#  '중국 CNY',
#  '홍콩 HKD',
#  '대만 TWD',
#  '영국 GBP',
#  '오만 OMR',
#  '캐나다 CAD',
#  '스위스 CHF',
#  '스웨덴 SEK',
#  '호주 AUD',
#  '뉴질랜드 NZD',
#  '체코 CZK',
#  '칠레 CLP',
#  '터키 TRY',
#  '몽골 MNT',
#  '이스라엘 ILS',
#  '덴마크 DKK',
#  '노르웨이 NOK',
#  '사우디아라비아 SAR',
#  '쿠웨이트 KWD',
#  '바레인 BHD',
#  '아랍에미리트 AED',
#  '요르단 JOD',
#  '이집트 EGP',
#  '태국 THB',
#  '싱가포르 SGD',
#  '말레이시아 MYR',
#  '인도네시아 IDR 100',
#  '카타르 QAR',
#  '카자흐스탄 KZT',
#  '브루나이 BND',
#  '인도 INR',
#  '파키스탄 PKR',
#  '방글라데시 BDT',
#  '필리핀 PHP',
#  '멕시코 MXN',
#  '브라질 BRL',
#  '베트남 VND 100',
#  '남아프리카 공화국 ZAR',
#  '러시아 RUB',
#  '헝가리 HUF',
#  '폴란드 PLN']

# %%
# 통화에 걸려있는 링크 값 획득
# tit => <td class = 'tit'>....</td>
# td>a의 href 속성값
# marketindexCd=FX_USDKRW
# 링크에서 환율별 고유코드 획득
# ~/marketindex/exchangeDegreeCountQuote.nhn?
# marketindexCd=고유코드 => 당일 고시차수별 환율 변동정보
# results = list()
# for tit in tits:
#     b = {'na':tit.a.string.strip().split()[0], 'code':tit.a.string.strip().split()[1], 'ncode':tit.a['href'].split('=')[-1]}
# # 최종 결과물을 리스트 딕셔너리 형태로 출력
#     a.append(b)
# print(results)

results = [{'na':tit.a.string.strip().split()[0], 'code':tit.a.string.strip().split()[1], 'ncode':tit.a['href'].split('=')[-1]} for tit in soup.select('td.tit')]
print(results)
# Out:
# [{'na': '미국', 'code': 'USD', 'ncode': 'FX_USDKRW'}, {'na': '유럽연합', 'code': 'EUR', 'ncode': 'FX_EURKRW'}, {'na': '일본', 'code': 'JPY', 'ncode': 'FX_JPYKRW'}, {'na': '중국', 'code': 'CNY', 'ncode': 'FX_CNYKRW'}, {'na': '홍콩', 'code': 'HKD', 'ncode': 'FX_HKDKRW'}, {'na': '대만', 'code': 'TWD', 'ncode': 'FX_TWDKRW'}, {'na': '영국', 'code': 'GBP', 'ncode': 'FX_GBPKRW'}, {'na': '오만', 'code': 'OMR', 'ncode': 'FX_OMRKRW'}, {'na': '캐나다', 'code': 'CAD', 'ncode': 'FX_CADKRW'}, {'na': '스위스', 'code': 'CHF', 'ncode': 'FX_CHFKRW'}, {'na': '스웨덴', 'code': 'SEK', 'ncode': 'FX_SEKKRW'}, {'na': '호주', 'code': 'AUD', 'ncode': 'FX_AUDKRW'}, {'na': '뉴질랜드', 'code': 'NZD', 'ncode': 'FX_NZDKRW'}, {'na': '체코', 'code': 'CZK', 'ncode': 'FX_CZKKRW'}, {'na': '칠레', 'code': 'CLP', 'ncode': 'FX_CLPKRW'}, {'na': '터키', 'code': 'TRY', 'ncode': 'FX_TRYKRW'}, {'na': '몽골', 'code': 'MNT', 'ncode': 'FX_MNTKRW'}, {'na': '이스라엘', 'code': 'ILS', 'ncode': 'FX_ILSKRW'}, {'na': '덴마크', 'code': 'DKK', 'ncode': 'FX_DKKKRW'}, {'na': '노르웨이', 'code': 'NOK', 'ncode': 'FX_NOKKRW'}, {'na': '사우디아라비아', 'code': 'SAR', 'ncode': 'FX_SARKRW'}, {'na': '쿠웨이트', 'code': 'KWD', 'ncode': 'FX_KWDKRW'}, {'na': '바레인', 'code': 'BHD', 'ncode': 'FX_BHDKRW'}, {'na': '아랍에미리트', 'code': 'AED', 'ncode': 'FX_AEDKRW'}, {'na': '요르단', 'code': 'JOD', 'ncode': 'FX_JODKRW'}, {'na': '이집트', 'code': 'EGP', 'ncode': 'FX_EGPKRW'}, {'na': '태국', 'code': 'THB', 'ncode': 'FX_THBKRW'}, {'na': '싱가포르', 'code': 'SGD', 'ncode': 'FX_SGDKRW'}, {'na': '말레이시아', 'code': 'MYR', 'ncode': 'FX_MYRKRW'}, {'na': '인도네시아', 'code': 'IDR', 'ncode': 'FX_IDRKRW'}, {'na': '카타르', 'code': 'QAR', 'ncode': 'FX_QARKRW'}, {'na': '카자흐스탄', 'code': 'KZT', 'ncode': 'FX_KZTKRW'}, {'na': '브루나이', 'code': 'BND', 'ncode': 'FX_BNDKRW'}, {'na': '인도', 'code': 'INR', 'ncode': 'FX_INRKRW'}, {'na': '파키스탄', 'code': 'PKR', 'ncode': 'FX_PKRKRW'}, {'na': '방글라데시', 'code': 'BDT', 'ncode': 'FX_BDTKRW'}, {'na': '필리핀', 'code': 'PHP', 'ncode': 'FX_PHPKRW'}, {'na': '멕시코', 'code': 'MXN', 'ncode': 'FX_MXNKRW'}, {'na': '브라질', 'code': 'BRL', 'ncode': 'FX_BRLKRW'}, {'na': '베트남', 'code': 'VND', 'ncode': 'FX_VNDKRW'}, {'na': '남아프리카', 'code': '공화국', 'ncode': 'FX_ZARKRW'}, {'na': '러시아', 'code': 'RUB', 'ncode': 'FX_RUBKRW'}, {'na': '헝가리', 'code': 'HUF', 'ncode': 'FX_HUFKRW'}, {'na': '폴란드', 'code': 'PLN', 'ncode': 'FX_PLNKRW'}]

# %%
# 매매 기준율 데이터를 뽑아서 최종적인 데이터 한개의 구조
tds = soup.findAll('td')
print(len(tds))
a = list()
# i: 인덱스, td: 데이터 덩어리
# enumerate()는 데이터의 순서를 같이 리턴해줘서 인덱스를 활용한 연산 처리에 도움
for i,td in enumerate(tds): # 7의 배수로 세트가(환율 정보가 변경된다)
    # print(i, td)
    # 기준 매매가 출력 : 1, 8, 15 , ... 번째 td의 텍스트 값
    position = i%7
    if position == 0: # 통화명 정보
        dic = {'na':td.a.string.strip().split()[0], 'code':td.a.string.strip().split()[1], 'ncode':td.a['href'].split('=')[-1]}
        a.append(dic)
    elif position == 1: # 기준 매매가
        a[-1]['stdSell'] = td.string.strip()
print(a)
# Out:
# 308
# [{'na': '미국', 'code': 'USD', 'ncode': 'FX_USDKRW', 'stdSell': '1,125.20'}, {'na': '유럽연합', 'code': 'EUR', 'ncode': 'FX_EURKRW', 'stdSell': '1,273.67'}, {'na': '일본', 'code': 'JPY', 'ncode': 'FX_JPYKRW', 'stdSell': '1,023.33'}, {'na': '중국', 'code': 'CNY', 'ncode': 'FX_CNYKRW', 'stdSell': '165.76'}, {'na': '홍콩', 'code': 'HKD', 'ncode': 'FX_HKDKRW', 'stdSell': '143.38'}, {'na': '대만', 'code': 'TWD', 'ncode': 'FX_TWDKRW', 'stdSell': '36.46'}, {'na': '영국', 'code': 'GBP', 'ncode': 'FX_GBPKRW', 'stdSell': '1,454.83'}, {'na': '오만', 'code': 'OMR', 'ncode': 'FX_OMRKRW', 'stdSell': '2,922.60'}, {'na': '캐나다', 'code': 'CAD', 'ncode': 'FX_CADKRW', 'stdSell': '846.30'}, {'na': '스위스', 'code': 'CHF', 'ncode': 'FX_CHFKRW', 'stdSell': '1,125.14'}, {'na': '스웨덴', 'code': 'SEK', 'ncode': 'FX_SEKKRW', 'stdSell': '121.31'}, {'na': '호주', 'code': 'AUD', 'ncode': 'FX_AUDKRW', 'stdSell': '797.77'}, {'na': '뉴질랜드', 'code': 'NZD', 'ncode': 'FX_NZDKRW', 'stdSell': '760.35'}, {'na': '체코', 'code': 'CZK', 'ncode': 'FX_CZKKRW', 'stdSell': '49.33'}, {'na': '칠레', 'code': 'CLP', 'ncode': 'FX_CLPKRW', 'stdSell': '1.71'}, {'na': '터키', 'code': 'TRY', 'ncode': 'FX_TRYKRW', 'stdSell': '214.32'}, {'na': '몽골', 'code': 'MNT', 'ncode': 'FX_MNTKRW', 'stdSell': '0.43'}, {'na': '이스라엘', 'code': 'ILS', 'ncode': 'FX_ILSKRW', 'stdSell': '309.00'}, {'na': '덴마크', 'code': 'DKK', 'ncode': 'FX_DKKKRW', 'stdSell': '170.65'}, {'na': '노르웨이', 'code': 'NOK', 'ncode': 'FX_NOKKRW', 'stdSell': '130.10'}, {'na': '사우디아라비아', 'code': 'SAR', 'ncode': 'FX_SARKRW', 'stdSell': '300.03'}, {'na': '쿠웨이트', 'code': 'KWD', 'ncode': 'FX_KWDKRW', 'stdSell': '3,703.75'}, {'na': '바레인', 'code': 'BHD', 'ncode': 'FX_BHDKRW', 'stdSell': '2,984.54'}, {'na': '아랍에미리트', 'code': 'AED', 'ncode': 'FX_AEDKRW', 'stdSell': '306.34'}, {'na': '요르단', 'code': 'JOD', 'ncode': 'FX_JODKRW', 'stdSell': '1,585.91'}, {'na': '이집트', 'code': 'EGP', 'ncode': 'FX_EGPKRW', 'stdSell': '63.80'}, {'na': '태국', 'code': 'THB', 'ncode': 'FX_THBKRW', 'stdSell': '35.77'}, {'na': '싱가포르', 'code': 'SGD', 'ncode': 'FX_SGDKRW', 'stdSell': '829.18'}, {'na': '말레이시아', 'code': 'MYR', 'ncode': 'FX_MYRKRW', 'stdSell': '276.29'}, {'na': '인도네시아', 'code': 'IDR', 'ncode': 'FX_IDRKRW', 'stdSell': '8.03'}, {'na': '카타르', 'code': 'QAR', 'ncode': 'FX_QARKRW', 'stdSell': '309.04'}, {'na': '카자흐스탄', 'code': 'KZT', 'ncode': 'FX_KZTKRW', 'stdSell': '3.00'}, {'na': '브루나이', 'code': 'BND', 'ncode': 'FX_BNDKRW', 'stdSell': '829.18'}, {'na': '인도', 'code': 'INR', 'ncode': 'FX_INRKRW', 'stdSell': '15.80'}, {'na': '파키스탄', 'code': 'PKR', 'ncode': 'FX_PKRKRW', 'stdSell': '8.05'}, {'na': '방글라데시', 'code': 'BDT', 'ncode': 'FX_BDTKRW', 'stdSell': '13.40'}, {'na': '필리핀', 'code': 'PHP', 'ncode': 'FX_PHPKRW', 'stdSell': '21.63'}, {'na': '멕시코', 'code': 'MXN', 'ncode': 'FX_MXNKRW', 'stdSell': '58.90'}, {'na': '브라질', 'code': 'BRL', 'ncode': 'FX_BRLKRW', 'stdSell': '301.49'}, {'na': '베트남', 'code': 'VND', 'ncode': 'FX_VNDKRW', 'stdSell': '4.85'}, {'na': '남아프리카', 'code': '공화국', 'ncode': 'FX_ZARKRW', 'stdSell': '82.67'}, {'na': '러시아', 'code': 'RUB', 'ncode': 'FX_RUBKRW', 'stdSell': '17.17'}, {'na': '헝가리', 'code': 'HUF', 'ncode': 'FX_HUFKRW', 'stdSell': '3.99'}, {'na': '폴란드', 'code': 'PLN', 'ncode': 'FX_PLNKRW', 'stdSell': '295.42'}]

# %%
import pymysql 
from sqlalchemy import create_engine
import pandas as pd
import pandas.io.sql as pSql

# %%
df_dict = pd.DataFrame.from_dict(a)
db_url = 'mysql+pymysql://root:1234@127.0.0.1/python_db'
engine = create_engine(db_url, encoding = 'utf8')
conn = engine.connect()
df_dict.to_sql( name = 'currency', con=conn, if_exists='append', index = False )
